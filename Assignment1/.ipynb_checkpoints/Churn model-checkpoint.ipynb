# %%
#Packages

import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator,TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.compose import make_column_transformer
from sklearn.compose import make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
import category_encoders as ce
from sklearn import metrics
from imblearn.over_sampling import SMOTE,ADASYN
from sklearn.linear_model import LogisticRegression
from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.model_selection import KFold
from imblearn.pipeline import Pipeline as imbPipeline
from sklearn.pipeline import FeatureUnion
#https://ourpython.com/python/python-imblearn-make-pipeline-typeerror-last-step-of-pipeline-should-implement


from sklearn.decomposition import PCA


#Own .py-scripts
# %run models_functions.py

# %% [markdown]
# https://dorukkilitcioglu.com/2018/08/11/pca-decision-tree.html
#
# Why you should use PCA before Decision Trees

# %%
# Import data from CSV-files
train_month_1 = pd.read_csv('data/train_month_1.csv', sep=",", header=0)
train_month_2 = pd.read_csv('data/train_month_2.csv', sep=",", header=0)
train_month_3 = pd.read_csv('data/train_month_3_with_target.csv', sep=",", header=0)
test_month_1 = pd.read_csv('data/test_month_1.csv', sep=",", header=0)
test_month_2 = pd.read_csv('data/test_month_2.csv', sep=",", header=0)
test_month_3 = pd.read_csv('data/test_month_3.csv', sep=",", header=0)

# %% [markdown]
# # data preprocessing

# %% [markdown]
# "RemoveMissinVvalueCol" transformer reduce the dataset extent by only allowing columns to exhibit at least 80% real values.
# Categorical Pipeline
#
# The dataset contains a mix of categorical and numerical independent variables, all of which must be pre-processed independently and in different ways. This implies they'll have to go through different pipelines to be properly pre-processed , and then we'll combine them. As a result, the first step in both pipelines would have to provide the necessary columns for pre-processing.
#
# "Categorical transformer" and "Numerical transformer"  are used to do data Featurization 'customer_since_all', 'customer_since_bank'and  'customer_birth_date' are available in the form of date However, date itself is not suitable to serve as an input for some machine learning models. Hence, we construct another set of features which are more interpretable
# and meaningful based on these date features. "Categorical transformer" results in
# 'customer_age' By subtracting todays date with birth year divided by "np.timedelta64(1, 'Y')" after that age is bin into equal intervals ,bin postal_code to respective province,converts values to Binary if its represented by zeros and ones. "Numerical transformer" results in'customer_all_dur'The number of days between todays date and customer_since_all
# and 'customer_bank_dur' The number of days between todays date and customer_since_bank.
#
#
# "Categorical transformer" and a SimpleImputer that replace the missing values with the most frequent value of the specific column is passed to the categorical_pipeline.
# "Numerical transformer", SimpleImputer that replace missing values with median of the specific column and a standardscaler
# is passed to the numerical_pipeline. Afterwards both pipeline are combined by a column transformer into preprocessor
#
#
# The problem of class imbalance makes classification more difficult. Because the number of churners is less than 5%, the dataset is unbalanced. Throughout the training process, some sampling approaches, such as oversampling, undersampling, or smart sampling, as well as measures other than accuracy, are required.

# %%
X = train_month_3.drop(['target','client_id'], axis=1)
y = train_month_3['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=42, stratify=y)

X_test2 = test_month_3.drop(['client_id'], axis=1)

X_train.head()
# Out:
#        homebanking_active  has_homebanking  has_insurance_21  \
# 51335                   0                0                 0
# 17614                   0                0                 0
# 17503                   0                0                 1
# 30421                   0                0                 0
# 29781                   0                0                 0
#
#        has_insurance_23  has_life_insurance_fixed_cap  \
# 51335                 0                             0
# 17614                 0                             0
# 17503                 0                             0
# 30421                 0                             0
# 29781                 0                             0
#
#        has_life_insurance_decreasing_cap  has_fire_car_other_insurance  \
# 51335                                  0                             1
# 17614                                  0                             0
# 17503                                  0                             1
# 30421                                  0                             0
# 29781                                  0                             0
#
#        has_personal_loan  has_mortgage_loan  has_current_account  ...  \
# 51335                  0                  0                    0  ...
# 17614                  0                  0                    1  ...
# 17503                  0                  0                    1  ...
# 30421                  0                  0                    0  ...
# 29781                  0                  0                    0  ...
#
#        customer_since_all  customer_since_bank  customer_gender  \
# 51335             1997-10              2004-01                1
# 17614             1992-04              1992-04                1
# 17503             1997-02              1997-02                1
# 30421             1994-07              1994-07                1
# 29781             1981-01              1981-01                1
#
#        customer_birth_date  customer_postal_code  customer_occupation_code  \
# 51335              1934-03                  9120                       9.0
# 17614              1942-10                  2018                       9.0
# 17503              1934-11                  9968                       9.0
# 30421              1955-01                  9120                       9.0
# 29781              1943-09                  3960                       9.0
#
#        customer_self_employed  customer_education  customer_children  \
# 51335                       0                 NaN                NaN
# 17614                       0                 NaN                 no
# 17503                       0                 NaN                NaN
# 30421                       0                 NaN                 no
# 29781                       0                 NaN                 no
#
#        customer_relationship
# 51335                    NaN
# 17614                 couple
# 17503                    NaN
# 30421                 couple
# 29781                 couple
#
# [5 rows x 38 columns]

# %%
y_train.value_counts()
# Out:
# 0    46337
# 1     1435
# Name: target, dtype: int64

# %%
(1435/46337) * 100
# Out:
# 3.0968772255433024

# %%
y_test.value_counts()
# Out:
# 0    15447
# 1      478
# Name: target, dtype: int64

# %% [markdown]
# Combining Random Oversampling and Undersampling
# https://towardsdatascience.com/class-imbalance-smote-borderline-smote-adasyn-6e36c78d804

# %%
df = X_train.copy()

# %%
# Checking the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47772 entries, 51335 to 17120
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   homebanking_active                 47772 non-null  int64
#  1   has_homebanking                    47772 non-null  int64
#  2   has_insurance_21                   47772 non-null  int64
#  3   has_insurance_23                   47772 non-null  int64
#  4   has_life_insurance_fixed_cap       47772 non-null  int64
#  5   has_life_insurance_decreasing_cap  47772 non-null  int64
#  6   has_fire_car_other_insurance       47772 non-null  int64
#  7   has_personal_loan                  47772 non-null  int64
#  8   has_mortgage_loan                  47772 non-null  int64
#  9   has_current_account                47772 non-null  int64
#  10  has_pension_saving                 47772 non-null  int64
#  11  has_savings_account                47772 non-null  int64
#  12  has_savings_account_starter        47772 non-null  int64
#  13  has_current_account_starter        47772 non-null  int64
#  14  bal_insurance_21                   47772 non-null  int64
#  15  bal_insurance_23                   47772 non-null  int64
#  16  cap_life_insurance_fixed_cap       47772 non-null  int64
#  17  cap_life_insurance_decreasing_cap  47772 non-null  int64
#  18  prem_fire_car_other_insurance      47772 non-null  int64
#  19  bal_personal_loan                  47772 non-null  int64
#  20  bal_mortgage_loan                  47772 non-null  int64
#  21  bal_current_account                47772 non-null  int64
#  22  bal_pension_saving                 47772 non-null  int64
#  23  bal_savings_account                47772 non-null  int64
#  24  bal_savings_account_starter        47772 non-null  int64
#  25  bal_current_account_starter        47772 non-null  int64
#  26  visits_distinct_so                 47772 non-null  float64
#  27  visits_distinct_so_areas           47772 non-null  float64
#  28  customer_since_all                 47602 non-null  object
#  29  customer_since_bank                47589 non-null  object
#  30  customer_gender                    47772 non-null  int64
#  31  customer_birth_date                47772 non-null  object
#  32  customer_postal_code               47772 non-null  int64
#  33  customer_occupation_code           46301 non-null  float64
#  34  customer_self_employed             47772 non-null  int64
#  35  customer_education                 12479 non-null  float64
#  36  customer_children                  30220 non-null  object
#  37  customer_relationship              36594 non-null  object
# dtypes: float64(4), int64(29), object(5)
# memory usage: 14.2+ MB

# %%
df.isna().sum()
# Out:
# homebanking_active                       0
# has_homebanking                          0
# has_insurance_21                         0
# has_insurance_23                         0
# has_life_insurance_fixed_cap             0
# has_life_insurance_decreasing_cap        0
# has_fire_car_other_insurance             0
# has_personal_loan                        0
# has_mortgage_loan                        0
# has_current_account                      0
# has_pension_saving                       0
# has_savings_account                      0
# has_savings_account_starter              0
# has_current_account_starter              0
# bal_insurance_21                         0
# bal_insurance_23                         0
# cap_life_insurance_fixed_cap             0
# cap_life_insurance_decreasing_cap        0
# prem_fire_car_other_insurance            0
# bal_personal_loan                        0
# bal_mortgage_loan                        0
# bal_current_account                      0
# bal_pension_saving                       0
# bal_savings_account                      0
# bal_savings_account_starter              0
# bal_current_account_starter              0
# visits_distinct_so                       0
# visits_distinct_so_areas                 0
# customer_since_all                     170
# customer_since_bank                    183
# customer_gender                          0
# customer_birth_date                      0
# customer_postal_code                     0
# customer_occupation_code              1471
# customer_self_employed                   0
# customer_education                   35293
# customer_children                    17552
# customer_relationship                11178
# dtype: int64

# %%
# We further reduce the dataset extent by only allowing columns to exhibit at least 80% real values.
df.dropna(thresh=0.8*len(X_train),axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# homebanking_active                      0
# has_homebanking                         0
# has_insurance_21                        0
# has_insurance_23                        0
# has_life_insurance_fixed_cap            0
# has_life_insurance_decreasing_cap       0
# has_fire_car_other_insurance            0
# has_personal_loan                       0
# has_mortgage_loan                       0
# has_current_account                     0
# has_pension_saving                      0
# has_savings_account                     0
# has_savings_account_starter             0
# has_current_account_starter             0
# bal_insurance_21                        0
# bal_insurance_23                        0
# cap_life_insurance_fixed_cap            0
# cap_life_insurance_decreasing_cap       0
# prem_fire_car_other_insurance           0
# bal_personal_loan                       0
# bal_mortgage_loan                       0
# bal_current_account                     0
# bal_pension_saving                      0
# bal_savings_account                     0
# bal_savings_account_starter             0
# bal_current_account_starter             0
# visits_distinct_so                      0
# visits_distinct_so_areas                0
# customer_since_all                    170
# customer_since_bank                   183
# customer_gender                         0
# customer_birth_date                     0
# customer_postal_code                    0
# customer_occupation_code             1471
# customer_self_employed                  0
# dtype: int64

# %%
df.head()
# Out:
#        homebanking_active  has_homebanking  has_insurance_21  \
# 51335                   0                0                 0
# 17614                   0                0                 0
# 17503                   0                0                 1
# 30421                   0                0                 0
# 29781                   0                0                 0
#
#        has_insurance_23  has_life_insurance_fixed_cap  \
# 51335                 0                             0
# 17614                 0                             0
# 17503                 0                             0
# 30421                 0                             0
# 29781                 0                             0
#
#        has_life_insurance_decreasing_cap  has_fire_car_other_insurance  \
# 51335                                  0                             1
# 17614                                  0                             0
# 17503                                  0                             1
# 30421                                  0                             0
# 29781                                  0                             0
#
#        has_personal_loan  has_mortgage_loan  has_current_account  ...  \
# 51335                  0                  0                    0  ...
# 17614                  0                  0                    1  ...
# 17503                  0                  0                    1  ...
# 30421                  0                  0                    0  ...
# 29781                  0                  0                    0  ...
#
#        bal_current_account_starter  visits_distinct_so  \
# 51335                            0                 2.0
# 17614                            0                 1.0
# 17503                            0                 2.0
# 30421                            0                 1.0
# 29781                            0                 1.0
#
#        visits_distinct_so_areas  customer_since_all  customer_since_bank  \
# 51335                       1.0             1997-10              2004-01
# 17614                       1.0             1992-04              1992-04
# 17503                       1.0             1997-02              1997-02
# 30421                       1.0             1994-07              1994-07
# 29781                       1.0             1981-01              1981-01
#
#        customer_gender  customer_birth_date  customer_postal_code  \
# 51335                1              1934-03                  9120
# 17614                1              1942-10                  2018
# 17503                1              1934-11                  9968
# 30421                1              1955-01                  9120
# 29781                1              1943-09                  3960
#
#        customer_occupation_code  customer_self_employed
# 51335                       9.0                       0
# 17614                       9.0                       0
# 17503                       9.0                       0
# 30421                       9.0                       0
# 29781                       9.0                       0
#
# [5 rows x 35 columns]

# %%
cat = CategoricalTransformer()

# %%
cat.fit_transform(df)
# Out:
#       homebanking_active has_homebanking has_insurance_21 has_insurance_23  \
# 51335                 No              No               No               No
# 17614                 No              No               No               No
# 17503                 No              No              Yes               No
# 30421                 No              No               No               No
# 29781                 No              No               No               No
# ...                  ...             ...              ...              ...
# 22320                 No              No               No               No
# 56274                 No              No               No               No
# 42417                 No              No               No               No
# 36415                 No              No               No               No
# 17120                 No              No               No               No
#
#       has_life_insurance_fixed_cap has_life_insurance_decreasing_cap  \
# 51335                           No                                No
# 17614                           No                                No
# 17503                           No                                No
# 30421                           No                                No
# 29781                           No                                No
# ...                            ...                               ...
# 22320                           No                                No
# 56274                           No                                No
# 42417                           No                                No
# 36415                           No                                No
# 17120                           No                                No
#
#       has_fire_car_other_insurance has_personal_loan has_mortgage_loan  \
# 51335                          Yes                No                No
# 17614                           No                No                No
# 17503                          Yes                No                No
# 30421                           No                No                No
# 29781                           No                No                No
# ...                            ...               ...               ...
# 22320                          Yes                No                No
# 56274                          Yes                No                No
# 42417                           No                No                No
# 36415                           No                No                No
# 17120                          Yes                No                No
#
#       has_current_account  ... bal_current_account_starter visits_distinct_so  \
# 51335                  No  ...                           0                2.0
# 17614                 Yes  ...                           0                1.0
# 17503                 Yes  ...                           0                2.0
# 30421                  No  ...                           0                1.0
# 29781                  No  ...                           0                1.0
# ...                   ...  ...                         ...                ...
# 22320                  No  ...                           0                1.0
# 56274                  No  ...                           0                1.0
# 42417                  No  ...                           0                1.0
# 36415                  No  ...                           0                1.0
# 17120                 Yes  ...                           0                1.0
#
#       visits_distinct_so_areas customer_since_all  customer_since_bank  \
# 51335                      1.0            1997-10              2004-01
# 17614                      1.0            1992-04              1992-04
# 17503                      1.0            1997-02              1997-02
# 30421                      1.0            1994-07              1994-07
# 29781                      1.0            1981-01              1981-01
# ...                        ...                ...                  ...
# 22320                      1.0            1976-12              2007-11
# 56274                      1.0            2009-11              2016-10
# 42417                      1.0            1995-06              1995-06
# 36415                      1.0            2014-09              2014-09
# 17120                      1.0            1999-11              2004-11
#
#        customer_gender  customer_occupation_code  customer_self_employed  \
# 51335              Yes                       9.0                      No
# 17614              Yes                       9.0                      No
# 17503              Yes                       9.0                      No
# 30421              Yes                       9.0                      No
# 29781              Yes                       9.0                      No
# ...                ...                       ...                     ...
# 22320              Yes                       9.0                      No
# 56274              Yes                       9.0                      No
# 42417              Yes                       9.0                      No
# 36415              Yes                       9.0                      No
# 17120              Yes                       9.0                      No
#
#               province  customer_age
# 51335  Oost-Vlaanderen       [80,90[
# 17614        Antwerpen       [70,80[
# 17503  Oost-Vlaanderen       [80,90[
# 30421  Oost-Vlaanderen       [60,70[
# 29781          Limburg       [70,80[
# ...                ...           ...
# 22320          Limburg       [70,80[
# 56274          Limburg       [70,80[
# 42417  Oost-Vlaanderen       [80,90[
# 36415    Waals-Brabant       [70,80[
# 17120             Luik       [60,70[
#
# [47772 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['homebanking_active', 'has_homebanking', 'has_insurance_21',
#        'has_insurance_23', 'has_life_insurance_fixed_cap',
#        'has_life_insurance_decreasing_cap', 'has_fire_car_other_insurance',
#        'has_personal_loan', 'has_mortgage_loan', 'has_current_account',
#        'has_pension_saving', 'has_savings_account',
#        'has_savings_account_starter', 'has_current_account_starter',
#        'bal_insurance_21', 'bal_insurance_23', 'cap_life_insurance_fixed_cap',
#        'cap_life_insurance_decreasing_cap', 'prem_fire_car_other_insurance',
#        'bal_personal_loan', 'bal_mortgage_loan', 'bal_current_account',
#        'bal_pension_saving', 'bal_savings_account',
#        'bal_savings_account_starter', 'bal_current_account_starter',
#        'visits_distinct_so', 'visits_distinct_so_areas', 'customer_since_all',
#        'customer_since_bank', 'customer_gender', 'customer_occupation_code',
#        'customer_self_employed', 'province', 'customer_age'],
#       dtype='object')

# %%
df.describe()
# Out:
#        bal_insurance_21  bal_insurance_23  cap_life_insurance_fixed_cap  \
# count      47772.000000      47772.000000                  47772.000000
# mean         460.575860         47.538098                     82.007243
# std         1645.817357        538.036321                   2673.186811
# min            0.000000          0.000000                      0.000000
# 25%            0.000000          0.000000                      0.000000
# 50%            0.000000          0.000000                      0.000000
# 75%            0.000000          0.000000                      0.000000
# max        10000.000000       9880.000000                 220000.000000
#
#        cap_life_insurance_decreasing_cap  prem_fire_car_other_insurance  \
# count                       47772.000000                   47772.000000
# mean                        11510.685548                     183.619275
# std                         39883.756920                     367.874849
# min                             0.000000                       0.000000
# 25%                             0.000000                       0.000000
# 50%                             0.000000                       0.000000
# 75%                             0.000000                     240.000000
# max                        780000.000000                    2960.000000
#
#        bal_personal_loan  bal_mortgage_loan  bal_current_account  \
# count        47772.00000       47772.000000         47772.000000
# mean           400.81889        8807.951729          1317.485556
# std           2644.14077       35276.394540          2679.061420
# min              0.00000           0.000000         -1000.000000
# 25%              0.00000           0.000000             0.000000
# 50%              0.00000           0.000000             0.000000
# 75%              0.00000           0.000000          1510.000000
# max          69160.00000      486990.000000         20000.000000
#
#        bal_pension_saving  bal_savings_account  bal_savings_account_starter  \
# count        47772.000000         47772.000000                 47772.000000
# mean           235.171858         17888.433601                    54.297078
# std           2144.281160         11774.262561                   860.658157
# min              0.000000             0.000000                     0.000000
# 25%              0.000000          8420.000000                     0.000000
# 50%              0.000000         15170.000000                     0.000000
# 75%              0.000000         25500.000000                     0.000000
# max          41170.000000         50000.000000                 23480.000000
#
#        bal_current_account_starter  visits_distinct_so  \
# count                 47772.000000        47772.000000
# mean                     32.299045            1.230909
# std                     423.247660            0.502112
# min                    -170.000000            1.000000
# 25%                       0.000000            1.000000
# 50%                       0.000000            1.000000
# 75%                       0.000000            1.000000
# max                   19790.000000            6.000000
#
#        visits_distinct_so_areas  customer_occupation_code
# count              47772.000000              46301.000000
# mean                   1.042410                  8.774454
# std                    0.224052                  1.128596
# min                    1.000000                  0.000000
# 25%                    1.000000                  9.000000
# 50%                    1.000000                  9.000000
# 75%                    1.000000                  9.000000
# max                    6.000000                  9.000000

# %%
num = NumericalTransformer()

# %%
num.fit_transform(df)
# Out:
#       homebanking_active has_homebanking has_insurance_21 has_insurance_23  \
# 51335                 No              No               No               No
# 17614                 No              No               No               No
# 17503                 No              No              Yes               No
# 30421                 No              No               No               No
# 29781                 No              No               No               No
# ...                  ...             ...              ...              ...
# 22320                 No              No               No               No
# 56274                 No              No               No               No
# 42417                 No              No               No               No
# 36415                 No              No               No               No
# 17120                 No              No               No               No
#
#       has_life_insurance_fixed_cap has_life_insurance_decreasing_cap  \
# 51335                           No                                No
# 17614                           No                                No
# 17503                           No                                No
# 30421                           No                                No
# 29781                           No                                No
# ...                            ...                               ...
# 22320                           No                                No
# 56274                           No                                No
# 42417                           No                                No
# 36415                           No                                No
# 17120                           No                                No
#
#       has_fire_car_other_insurance has_personal_loan has_mortgage_loan  \
# 51335                          Yes                No                No
# 17614                           No                No                No
# 17503                          Yes                No                No
# 30421                           No                No                No
# 29781                           No                No                No
# ...                            ...               ...               ...
# 22320                          Yes                No                No
# 56274                          Yes                No                No
# 42417                           No                No                No
# 36415                           No                No                No
# 17120                          Yes                No                No
#
#       has_current_account  ... bal_current_account_starter visits_distinct_so  \
# 51335                  No  ...                           0                2.0
# 17614                 Yes  ...                           0                1.0
# 17503                 Yes  ...                           0                2.0
# 30421                  No  ...                           0                1.0
# 29781                  No  ...                           0                1.0
# ...                   ...  ...                         ...                ...
# 22320                  No  ...                           0                1.0
# 56274                  No  ...                           0                1.0
# 42417                  No  ...                           0                1.0
# 36415                  No  ...                           0                1.0
# 17120                 Yes  ...                           0                1.0
#
#       visits_distinct_so_areas customer_gender  customer_occupation_code  \
# 51335                      1.0             Yes                       9.0
# 17614                      1.0             Yes                       9.0
# 17503                      1.0             Yes                       9.0
# 30421                      1.0             Yes                       9.0
# 29781                      1.0             Yes                       9.0
# ...                        ...             ...                       ...
# 22320                      1.0             Yes                       9.0
# 56274                      1.0             Yes                       9.0
# 42417                      1.0             Yes                       9.0
# 36415                      1.0             Yes                       9.0
# 17120                      1.0             Yes                       9.0
#
#        customer_self_employed         province  customer_age  \
# 51335                      No  Oost-Vlaanderen       [80,90[
# 17614                      No        Antwerpen       [70,80[
# 17503                      No  Oost-Vlaanderen       [80,90[
# 30421                      No  Oost-Vlaanderen       [60,70[
# 29781                      No          Limburg       [70,80[
# ...                       ...              ...           ...
# 22320                      No          Limburg       [70,80[
# 56274                      No          Limburg       [70,80[
# 42417                      No  Oost-Vlaanderen       [80,90[
# 36415                      No    Waals-Brabant       [70,80[
# 17120                      No             Luik       [60,70[
#
#        customer_all_dur  customer_bank_dur
# 51335            9005.0             6722.0
# 17614           11014.0            11014.0
# 17503            9247.0             9247.0
# 30421           10193.0            10193.0
# 29781           15122.0            15122.0
# ...                 ...                ...
# 22320           16614.0             5322.0
# 56274            4591.0             2065.0
# 42417            9858.0             9858.0
# 36415            2826.0             2826.0
# 17120            8244.0             6417.0
#
# [47772 rows x 35 columns]

# %%
filter_col = [col for col in df if col.startswith('has_')] + ['customer_gender','customer_occupation_code','customer_self_employed','customer_postal_code',"homebanking_active",'customer_birth_date']
filter_col
filter_col2 = [col for col in df if col.startswith('bal_')] + ['cap_life_insurance_fixed_cap', 'cap_life_insurance_decreasing_cap',
                                                                 'prem_fire_car_other_insurance','visits_distinct_so', 'visits_distinct_so_areas','customer_since_all','customer_since_bank']
filter_col2

filter = filter_col + filter_col2
len(filter_col) + len(filter_col2)
filter
# Out:
# ['has_homebanking',
#  'has_insurance_21',
#  'has_insurance_23',
#  'has_life_insurance_fixed_cap',
#  'has_life_insurance_decreasing_cap',
#  'has_fire_car_other_insurance',
#  'has_personal_loan',
#  'has_mortgage_loan',
#  'has_current_account',
#  'has_pension_saving',
#  'has_savings_account',
#  'has_savings_account_starter',
#  'has_current_account_starter',
#  'customer_gender',
#  'customer_occupation_code',
#  'customer_self_employed',
#  'customer_postal_code',
#  'homebanking_active',
#  'customer_birth_date',
#  'bal_insurance_21',
#  'bal_insurance_23',
#  'bal_personal_loan',
#  'bal_mortgage_loan',
#  'bal_current_account',
#  'bal_pension_saving',
#  'bal_savings_account',
#  'bal_savings_account_starter',
#  'bal_current_account_starter',
#  'cap_life_insurance_fixed_cap',
#  'cap_life_insurance_decreasing_cap',
#  'prem_fire_car_other_insurance',
#  'visits_distinct_so',
#  'visits_distinct_so_areas',
#  'customer_since_all',
#  'customer_since_bank']

# %%
len(filter)
# Out:
# 35

# %%
numerical_pipeline = make_pipeline(NumericalTransformer(),SimpleImputer(strategy='median',add_indicator = True),StandardScaler())
categorical_pipeline = make_pipeline(CategoricalTransformer(),SimpleImputer(strategy='most_frequent',add_indicator = True),ce.BinaryEncoder())

# preprocessor = FeatureUnion( transformer_list = [ ( 'categorical_pipeline', categorical_pipeline ), 
                                                  
#                                                   ( 'numerical_pipeline', numerical_pipeline ) ] )

preprocessor = ColumnTransformer([
    ('cat', categorical_pipeline, filter_col),
    ('num', numerical_pipeline, filter_col2)
])

# %%
df = X_train.copy()

# %%
data = preprocessor.fit_transform(df)
data
# Out:
# array([[ 0.        ,  1.        ,  0.        , ..., -0.15557675,
#         -0.05976018, -0.0620115 ],
#        [ 0.        ,  1.        ,  0.        , ...,  0.90812769,
#         -0.05976018, -0.0620115 ],
#        [ 0.        ,  1.        ,  1.        , ...,  0.47020464,
#         -0.05976018, -0.0620115 ],
#        ...,
#        [ 0.        ,  1.        ,  0.        , ...,  0.62163134,
#         -0.05976018, -0.0620115 ],
#        [ 0.        ,  1.        ,  0.        , ..., -1.12113885,
#         -0.05976018, -0.0620115 ],
#        [ 0.        ,  1.        ,  0.        , ..., -0.23116619,
#         -0.05976018, -0.0620115 ]])

# %%
data.shape
# Out:
# (47772, 65)

# %%
# define oversampling strategy
over = RandomOverSampler(random_state=99)
# define undersampling strategy
under = RandomUnderSampler()

# over = ADASYN(random_state=99)
# over = SMOTE(sampling_strategy=0.1)
# under = RandomUnderSampler(sampling_strategy=0.5)

# %%
model =imbPipeline(steps=[('RemoveMissinVvalueCol',RemoveMissinVvalueCol(0.8)),
                                  ('preprocessor', preprocessor),
                        
                        ('o', over),
                    
                      ('classifier', LogisticRegression(random_state=0, max_iter=500))])

# %%
# evaluation(model,X_train,y_train,X_test,y_test)

# %%
grid={'classifier__C':10.0 **np.arange(-2,3),'classifier__penalty':['l2',"none"],"classifier__solver":["sag","saga","lbfgs"],"classifier__max_iter":[500,550,600,650]}
cv=KFold(n_splits=5,random_state=None,shuffle=False)

# %%
clf=GridSearchCV(model,param_grid=grid,cv=cv,n_jobs=-1,scoring='f1_macro')
# clf.fit(X_train,y_train)
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('RemoveMissinVvalueCol',
#                                         RemoveMissinVvalueCol(treshold=0.8)),
#                                        ('preprocessor',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          Pipeline(steps=[('categoricaltransformer',
#                                                                                           CategoricalTransformer()),
#                                                                                          ('simpleimputer',
#                                                                                           SimpleImputer(add_indicator=True,
#                                                                                                         strategy='most_frequent...
#                                                                           'customer_since_bank'])])),
#                                        ('o',
#                                         RandomOverSampler(random_state=99)),
#                                        ('classifier',
#                                         LogisticRegression(max_iter=500,
#                                                            random_state=0))]),
#              n_jobs=-1,
#              param_grid={'classifier__C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02]),
#                          'classifier__max_iter': [500, 550, 600, 650],
#                          'classifier__penalty': ['l2', 'none'],
#                          'classifier__solver': ['sag', 'saga', 'lbfgs']},
#              scoring='f1_macro')

# %%
clf.best_params_
# Out:
# {'classifier__C': 0.01,
#  'classifier__max_iter': 550,
#  'classifier__penalty': 'l2',
#  'classifier__solver': 'saga'}

# %%
model =imbPipeline(steps=[('RemoveMissinVvalueCol',RemoveMissinVvalueCol(0.8)),
                                  ('preprocessor', preprocessor),
                        
                        ('o', over),
                    
                      ('classifier', LogisticRegression(random_state=0, C= 0.1,solver = 'sag', max_iter=550))])

# %%
model.fit(X_train,y_train)
pred=model.predict(X_test)

print(confusion_matrix(y_test,pred))
print("\n\n")
print(classification_report(y_test,pred))
# Out:
# Pipeline(steps=[('RemoveMissinVvalueCol', RemoveMissinVvalueCol(treshold=0.8)),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('categoricaltransformer',
#                                                                    CategoricalTransformer()),
#                                                                   ('simpleimputer',
#                                                                    SimpleImputer(add_indicator=True,
#                                                                                  strategy='most_frequent')),
#                                                                   ('binaryencoder',
#                                                                    BinaryEncoder())]),
#                                                   ['has_homebanking',
#                                                    'has_insurance_21...
#                                                    'bal_savings_account_starter',
#                                                    'bal_current_account_starter',
#                                                    'cap_life_insurance_fixed_cap',
#                                                    'cap_life_insurance_decreasing_cap',
#                                                    'prem_fire_car_other_insurance',
#                                                    'visits_distinct_so',
#                                                    'visits_distinct_so_areas',
#                                                    'customer_since_all',
#                                                    'customer_since_bank'])])),
#                 ('o', RandomOverSampler(random_state=99)),
#                 ('classifier',
#                  LogisticRegression(C=0.1, max_iter=550, random_state=0,
#                                     solver='sag'))])
# [[10285  5162]
#  [  166   312]]
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.67      0.79     15447
#            1       0.06      0.65      0.10       478
#
#     accuracy                           0.67     15925
#    macro avg       0.52      0.66      0.45     15925
# weighted avg       0.96      0.67      0.77     15925

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test, pred, pos_label=None)
print(metrics.auc(fpr, tpr))
# Out:
# 0.6496348832680136

# %%
y_pred = model.predict_proba(X_test2)
    
# Dataframe which contains the results
pred = pd.DataFrame()
pred['ID'] = test_month_3['client_id']
    
pred['PROB'] = y_pred[:, 1]
    
print(pred)
    
#Export data
# pred.to_csv('test.csv', index = False)

# %%
AdaBoostClassifier1 =imbPipeline(steps=[('RemoveMissinVvalueCol',RemoveMissinVvalueCol(0.8)),
                                  ('preprocessor', preprocessor),
                        
                        ('o', over),
                    
                      ('classifier', AdaBoostClassifier(random_state=99))])

# %%
evaluation(AdaBoostClassifier1,X_train,y_train,X_test,y_test)
# Out:
# 0.6520932826593185

# %%
parameters = {
  'classifier__n_estimators':[50,100,200,300,400,500],
    'SelectKBest__k':[10,15,20,25]
  }


# initialize
grid_pipeline = GridSearchCV(AdaBoost_samp,parameters,scoring='f1')
# fit
grid_pipeline.fit(X_train,y_train)
grid_pipeline.best_params_

# %%
AdaBoostClassifier1 =imbPipeline(steps=[('RemoveMissinVvalueCol',RemoveMissinVvalueCol(0.8)),
                                  ('preprocessor', preprocessor),
                        
                        ('o', over),
                    
                      ('classifier', AdaBoostClassifier(random_state=99,n_estimators=500))])

# %%
AdaBoostClassifier1.fit(X_train,y_train)
pred=AdaBoostClassifier.predict(X_test)

print(confusion_matrix(y_test,pred))
print("\n\n")
print(classification_report(y_test,pred))
# Out:
# Pipeline(steps=[('RemoveMissinVvalueCol', RemoveMissinVvalueCol(treshold=0.8)),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('categoricaltransformer',
#                                                                    CategoricalTransformer()),
#                                                                   ('simpleimputer',
#                                                                    SimpleImputer(add_indicator=True,
#                                                                                  strategy='most_frequent')),
#                                                                   ('binaryencoder',
#                                                                    BinaryEncoder())]),
#                                                   ['has_homebanking',
#                                                    'has_insurance_21...
#                                                    'bal_savings_account_starter',
#                                                    'bal_current_account_starter',
#                                                    'cap_life_insurance_fixed_cap',
#                                                    'cap_life_insurance_decreasing_cap',
#                                                    'prem_fire_car_other_insurance',
#                                                    'visits_distinct_so',
#                                                    'visits_distinct_so_areas',
#                                                    'customer_since_all',
#                                                    'customer_since_bank'])])),
#                 ('o', RandomOverSampler(random_state=99)),
#                 ('classifier',
#                  AdaBoostClassifier(n_estimators=500, random_state=99))])
# [[11086  4361]
#  [  200   278]]
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.72      0.83     15447
#            1       0.06      0.58      0.11       478
#
#     accuracy                           0.71     15925
#    macro avg       0.52      0.65      0.47     15925
# weighted avg       0.95      0.71      0.81     15925

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test, pred, pos_label=None)
print(metrics.auc(fpr, tpr))

# %%
easy= make_pipeline(RemoveMissinVvalueCol(0.8),preprocessor
                      ,EasyEnsembleClassifier(random_state=99,n_jobs=-1))

# %%
evaluation(easy,X_train,y_train,X_test,y_test)
# Out:
# 0.6514936482771566

# %%
grid = {
  'easyensembleclassifier__n_estimators':[10,15,20,30,40,50,100,200],
  }

clf=GridSearchCV(easy,param_grid=grid,cv=cv,n_jobs=-1,scoring='f1_macro')
# clf.fit(X_train,y_train)
clf.fit(X_train,y_train)
clf.best_params_
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('removemissinvvaluecol',
#                                         RemoveMissinVvalueCol(treshold=0.8)),
#                                        ('columntransformer',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          Pipeline(steps=[('categoricaltransformer',
#                                                                                           CategoricalTransformer()),
#                                                                                          ('simpleimputer',
#                                                                                           SimpleImputer(add_indicator=True,
#                                                                                                         strategy='most_fre...
#                                                                           'cap_life_insurance_fixed_cap',
#                                                                           'cap_life_insurance_decreasing_cap',
#                                                                           'prem_fire_car_other_insurance',
#                                                                           'visits_distinct_so',
#                                                                           'visits_distinct_so_areas',
#                                                                           'customer_since_all',
#                                                                           'customer_since_bank'])])),
#                                        ('easyensembleclassifier',
#                                         EasyEnsembleClassifier(random_state=99))]),
#              n_jobs=-1,
#              param_grid={'easyensembleclassifier__n_estimators': [10, 15, 20,
#                                                                   30, 40, 50,
#                                                                   100, 200]},
#              scoring='f1_macro')
# {'easyensembleclassifier__n_estimators': 10}

# %%
easy= make_pipeline(RemoveMissinVvalueCol(0.8),preprocessor
                      ,EasyEnsembleClassifier(random_state=99,n_jobs=-1))

easy.fit(X_train,y_train)
y_pred=easy.predict(X_test)
print(confusion_matrix(y_test,y_pred))
# print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Pipeline(steps=[('removemissinvvaluecol', RemoveMissinVvalueCol(treshold=0.8)),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('categoricaltransformer',
#                                                                    CategoricalTransformer()),
#                                                                   ('simpleimputer',
#                                                                    SimpleImputer(add_indicator=True,
#                                                                                  strategy='most_frequent')),
#                                                                   ('binaryencoder',
#                                                                    BinaryEncoder())]),
#                                                   ['has_homebanking',
#                                                    'has_insuran...
#                                                    'bal_savings_account',
#                                                    'bal_savings_account_starter',
#                                                    'bal_current_account_starter',
#                                                    'cap_life_insurance_fixed_cap',
#                                                    'cap_life_insurance_decreasing_cap',
#                                                    'prem_fire_car_other_insurance',
#                                                    'visits_distinct_so',
#                                                    'visits_distinct_so_areas',
#                                                    'customer_since_all',
#                                                    'customer_since_bank'])])),
#                 ('easyensembleclassifier',
#                  EasyEnsembleClassifier(n_jobs=-1, random_state=99))])
# [[10088  5359]
#  [  168   310]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.65      0.78     15447
#            1       0.05      0.65      0.10       478
#
#     accuracy                           0.65     15925
#    macro avg       0.52      0.65      0.44     15925
# weighted avg       0.96      0.65      0.76     15925

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test, pred, pos_label=None)
print(metrics.auc(fpr, tpr))
# Out:
# 0.6592723722876956

# %%
y_pred = easy.predict_proba(X_test2)
    
# Dataframe which contains the results
pred = pd.DataFrame()
pred['ID'] = test_month_3['client_id']
    
pred['PROB'] = y_pred[:, 1]
    
print(pred)
    
#Export data
# pred.to_csv('test1.csv', index = False)
# Out:
#                                      ID      PROB
# 0      ccf4cd93d5c32cd8a59809d54b4d53ac  0.503237
# 1      56605a660d18549592653ff6941186f1  0.499876
# 2      bda5f84c05e5695a7ec10550b457890f  0.507911
# 3      a2f1c04bc3acf2222e658a897400798f  0.498557
# 4      e83aadc3b0d25dbc12a35551afa25807  0.496926
# ...                                 ...       ...
# 27295  1a634b5cfe6dbf35e77ce6519c0e3939  0.503037
# 27296  84b7af2ddbeb919ab238ef7e6a83936c  0.497173
# 27297  c257c09e3f4445d67b52a1007b0205df  0.496391
# 27298  fdd7a1b7e58f642a1fc4867b8f7cdf3a  0.498445
# 27299  9b088b828fa94419c00175b6536857f9  0.497800
#
# [27300 rows x 2 columns]

# %%
# dict_of_models = {'Logisticregression': model,
#                   'AdaBoost' : easy,
#                  }

# %%
# for name, model in dict_of_models.items():
#     print(name)
#     evaluation(model)
